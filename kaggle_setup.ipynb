# %% [markdown]
# # Vista Hackathon - Kaggle Setup
#
# This notebook helps you set up and run the training on Kaggle.

# %%
# 1. Clone the repository
# !rm -rf vista
# !git clone -b kaggle https://github.com/Woeter69/vista.git
# %cd vista

# %%
# 2. Install dependencies (Kaggle has most, but ensure everything is there)
# !pip install albumentations pycocotools opencv-python -U

# %%
# 3. Run Training (Winning Gold Configuration)
# Note: Change --data-dir to your actual Kaggle dataset path
# !python train.py \  --kaggle \  --data-dir "/kaggle/input/your-dataset-name" \  --epochs 20 \  --batch-size 4 \  --accum 8 \  --lr 0.0001 \  --mosaic \  --resume
